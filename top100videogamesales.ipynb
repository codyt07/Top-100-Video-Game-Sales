# %%
from itertools import groupby
import pandas as pd
import seaborn as sns
import csv
import matplotlib.pyplot as plt

# %%
# For MatPlotLib
input_file = 'top100videogamesales.csv'
plt.figure(figsize=(7, 4.25))
with open(input_file, 'r') as sales_data:
    sales_lib = list(csv.reader(sales_data))
sales_lib.pop()

# For Seaborn 
sns.set_theme(context='notebook', style='darkgrid', palette='deep', font_scale=1)
sales = pd.read_csv('top100videogamesales.csv')
sns.set(rc={"figure.figsize":(23, 10)}) #width, #height

# For Pandas
pandas = pd.read_csv('top100videogamesales.csv')

sales.head()
# Out:
#    Rank                   Name  Platform  Year     Genre Publisher  NA_Sales  \
# 0     1             Wii Sports  Nintendo  2006    Sports  Nintendo     41.49
# 1     2         Mario Kart Wii  Nintendo  2008    Racing  Nintendo     15.85
# 2     3      Wii Sports Resort  Nintendo  2009    Sports  Nintendo     15.75
# 3     4  New Super Mario Bros.  Nintendo  2006  Platform  Nintendo     11.38
# 4     5               Wii Play  Nintendo  2006      Misc  Nintendo     14.03
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1     12.88      3.79         3.31         35.82
# 2     11.01      3.28         2.96         33.00
# 3      9.23      6.50         2.90         30.01
# 4      9.20      2.93         2.85         29.02

# %% [markdown]
# ## Regional Sales by Publisher

# %% [markdown]
# #### NA Sales

# %%
sns.barplot(data=sales, hue='Publisher', x='Publisher', y="NA_Sales")
# Out:
# <AxesSubplot:xlabel='Publisher', ylabel='NA_Sales'>

# %% [markdown]
# ##### Microsoft Game Studios had the most NA Sales, while Electronic Arts had the least

# %% [markdown]
# ##### EU Sales

# %%
sns.barplot(data=sales, hue='Publisher', x='Publisher', y="EU_Sales")
# Out:
# <AxesSubplot:xlabel='Publisher', ylabel='EU_Sales'>

# %% [markdown]
# ##### Nintendo Had the Most EU Sales while Microsoft Game Studios had the least.

# %% [markdown]
# #### Japenese Sales

# %%
sns.barplot(data=sales, hue='Publisher', x='Publisher', y="JP_Sales")
# Out:
# <AxesSubplot:xlabel='Publisher', ylabel='JP_Sales'>

# %% [markdown]
# ##### Nintendo had the most JP Sales while Ubisoft and 505 Games had the lowest

# %% [markdown]
# #### Other Sales

# %%
sns.barplot(data=sales, hue='Publisher', x='Publisher', y="Other_Sales")
# Out:
# <AxesSubplot:xlabel='Publisher', ylabel='Other_Sales'>

# %% [markdown]
# #### Take Two Interactive had the most sales in the other category. Sega, Ubisoft, 505, and Microsoft Game Studios had the least

# %% [markdown]
# #### Global Sales

# %%
sns.barplot(data=sales, hue='Publisher', x='Publisher', y="Global_Sales")
# Out:
# <AxesSubplot:xlabel='Publisher', ylabel='Global_Sales'>

# %% [markdown]
# ##### Nintendo had the most global sales while 505 had the least
